# %% [markdown]
# # Practice for Filtering with SQL

# %% [markdown]
# Import the germane libraries and connect to the database.

# %%
# Run this code

import pandas as pd
import sqlite3

conn = sqlite3.connect('data.sqlite')
pd.read_sql("""
SELECT *
  FROM employees;
""", conn)
# Out:
#     employeeNumber   lastName firstName extension  \
# 0             1002     Murphy     Diane     x5800
# 1             1056  Patterson      Mary     x4611
# 2             1076   Firrelli      Jeff     x9273
# 3             1088  Patterson   William     x4871
# 4             1102     Bondur    Gerard     x5408
# 5             1143        Bow   Anthony     x5428
# 6             1165   Jennings    Leslie     x3291
# 7             1166   Thompson    Leslie     x4065
# 8             1188   Firrelli     Julie     x2173
# 9             1216  Patterson     Steve     x4334
# 10            1286      Tseng  Foon Yue     x2248
# 11            1323     Vanauf    George     x4102
# 12            1337     Bondur      Loui     x6493
# 13            1370  Hernandez    Gerard     x2028
# 14            1401   Castillo    Pamela     x2759
# 15            1501       Bott     Larry     x2311
# 16            1504      Jones     Barry      x102
# 17            1611     Fixter      Andy      x101
# 18            1612      Marsh     Peter      x102
# 19            1619       King       Tom      x103
# 20            1621      Nishi      Mami      x101
# 21            1625       Kato   Yoshimi      x102
# 22            1702     Gerard    Martin     x2312
#
#                               email  officeCode reportsTo  \
# 0      dmurphy@classicmodelcars.com           1
# 1    mpatterso@classicmodelcars.com           1      1002
# 2    jfirrelli@classicmodelcars.com           1      1002
# 3   wpatterson@classicmodelcars.com           6      1056
# 4      gbondur@classicmodelcars.com           4      1056
# 5         abow@classicmodelcars.com           1      1056
# 6    ljennings@classicmodelcars.com           1      1143
# 7    lthompson@classicmodelcars.com           1      1143
# 8    jfirrelli@classicmodelcars.com           2      1143
# 9   spatterson@classicmodelcars.com           2      1143
# 10      ftseng@classicmodelcars.com           3      1143
# 11     gvanauf@classicmodelcars.com           3      1143
# 12     lbondur@classicmodelcars.com           4      1102
# 13   ghernande@classicmodelcars.com           4      1102
# 14   pcastillo@classicmodelcars.com           4      1102
# 15       lbott@classicmodelcars.com           7      1102
# 16      bjones@classicmodelcars.com           7      1102
# 17     afixter@classicmodelcars.com           6      1088
# 18      pmarsh@classicmodelcars.com           6      1088
# 19       tking@classicmodelcars.com           6      1088
# 20      mnishi@classicmodelcars.com           5      1056
# 21       ykato@classicmodelcars.com           5      1621
# 22     mgerard@classicmodelcars.com           4      1102
#
#                 jobTitle
# 0              President
# 1               VP Sales
# 2           VP Marketing
# 3   Sales Manager (APAC)
# 4    Sale Manager (EMEA)
# 5     Sales Manager (NA)
# 6              Sales Rep
# 7              Sales Rep
# 8              Sales Rep
# 9              Sales Rep
# 10             Sales Rep
# 11             Sales Rep
# 12             Sales Rep
# 13             Sales Rep
# 14             Sales Rep
# 15             Sales Rep
# 16             Sales Rep
# 17             Sales Rep
# 18             Sales Rep
# 19             Sales Rep
# 20             Sales Rep
# 21             Sales Rep
# 22             Sales Rep

# %% [markdown]
# 1. Select all of the employees with first name "Leslie"

# %%
# Fist name Leslie
pd.read_sql("""
SELECT *
  FROM employees
  WHERE firstName = "Leslie";
""", conn)
# Out:
#    employeeNumber  lastName firstName extension  \
# 0            1165  Jennings    Leslie     x3291
# 1            1166  Thompson    Leslie     x4065
#
#                             email  officeCode  reportsTo   jobTitle
# 0  ljennings@classicmodelcars.com           1       1143  Sales Rep
# 1  lthompson@classicmodelcars.com           1       1143  Sales Rep

# %% [markdown]
# 2. For the employees named Leslie, give the first name, last name, and job title.

# %%
# First name Leslie, with last name and title
pd.read_sql("""
SELECT firstName, lastName, jobTitle
  FROM employees
  WHERE firstName = "Leslie";
""", conn)
# Out:
#   firstName  lastName   jobTitle
# 0    Leslie  Jennings  Sales Rep
# 1    Leslie  Thompson  Sales Rep

# %% [markdown]
# 3. Select all employees that have a last name less than 5. Using inequalities, do this in two different ways using conditionals.

# %%
# Strictly less than 5
pd.read_sql("""
SELECT *
  FROM employees
  WHERE LENGTH(lastName) < 5;
""", conn)
# Out:
#    employeeNumber lastName firstName extension                       email  \
# 0            1143      Bow   Anthony     x5428   abow@classicmodelcars.com
# 1            1501     Bott     Larry     x2311  lbott@classicmodelcars.com
# 2            1619     King       Tom      x103  tking@classicmodelcars.com
# 3            1625     Kato   Yoshimi      x102  ykato@classicmodelcars.com
#
#    officeCode  reportsTo            jobTitle
# 0           1       1056  Sales Manager (NA)
# 1           7       1102           Sales Rep
# 2           6       1088           Sales Rep
# 3           5       1621           Sales Rep

# %%
# Less than or equal to 4.
pd.read_sql("""
SELECT *
  FROM employees
  WHERE LENGTH(lastName) <= 4;
""", conn)
# Out:
#    employeeNumber lastName firstName extension                       email  \
# 0            1143      Bow   Anthony     x5428   abow@classicmodelcars.com
# 1            1501     Bott     Larry     x2311  lbott@classicmodelcars.com
# 2            1619     King       Tom      x103  tking@classicmodelcars.com
# 3            1625     Kato   Yoshimi      x102  ykato@classicmodelcars.com
#
#    officeCode  reportsTo            jobTitle
# 0           1       1056  Sales Manager (NA)
# 1           7       1102           Sales Rep
# 2           6       1088           Sales Rep
# 3           5       1621           Sales Rep

# %% [markdown]
# Now let's turn to the orderDetails database.

# %%
# Run this code

conn = sqlite3.connect('data.sqlite')
pd.read_sql("""
SELECT *
  FROM orderDetails;
""", conn)
# Out:
#       orderNumber productCode  quantityOrdered  priceEach  orderLineNumber
# 0           10100    S18_1749               30     136.00                3
# 1           10100    S18_2248               50      55.09                2
# 2           10100    S18_4409               22      75.46                4
# 3           10100    S24_3969               49      35.29                1
# 4           10101    S18_2325               25     108.06                4
# ...           ...         ...              ...        ...              ...
# 2991        10425    S24_2300               49     127.79                9
# 2992        10425    S24_2840               31      31.82                5
# 2993        10425    S32_1268               41      83.79               11
# 2994        10425    S32_2509               11      50.32                6
# 2995        10425    S50_1392               18      94.92                2
#
# [2996 rows x 5 columns]

# %% [markdown]
# 4. Round the price as an integer

# %%
# Rounding price
pd.read_sql("""
SELECT CAST(ROUND(priceEach) AS INT) AS rounded_price_int
  FROM orderDetails;
""", conn)
# Out:
#       rounded_price_int
# 0                   136
# 1                    55
# 2                    75
# 3                    35
# 4                   108
# ...                 ...
# 2991                128
# 2992                 32
# 2993                 84
# 2994                 50
# 2995                 95
#
# [2996 rows x 1 columns]

# %% [markdown]
# Let's look at the orders database.

# %%
# Run this code

conn = sqlite3.connect('data.sqlite')
pd.read_sql("""
SELECT *
  FROM orders;
""", conn)
# Out:
#      orderNumber   orderDate requiredDate shippedDate      status  \
# 0          10100  2003-01-06   2003-01-13  2003-01-10     Shipped
# 1          10101  2003-01-09   2003-01-18  2003-01-11     Shipped
# 2          10102  2003-01-10   2003-01-18  2003-01-14     Shipped
# 3          10103  2003-01-29   2003-02-07  2003-02-02     Shipped
# 4          10104  2003-01-31   2003-02-09  2003-02-01     Shipped
# ..           ...         ...          ...         ...         ...
# 321        10421  2005-05-29   2005-06-06              In Process
# 322        10422  2005-05-30   2005-06-11              In Process
# 323        10423  2005-05-30   2005-06-05              In Process
# 324        10424  2005-05-31   2005-06-08              In Process
# 325        10425  2005-05-31   2005-06-07              In Process
#
#                                               comments  customerNumber
# 0                                                                  363
# 1                               Check on availability.             128
# 2                                                                  181
# 3                                                                  121
# 4                                                                  141
# ..                                                 ...             ...
# 321  Custom shipping instructions were sent to ware...             124
# 322                                                                157
# 323                                                                314
# 324                                                                141
# 325                                                                119
#
# [326 rows x 7 columns]

# %% [markdown]
# 5. Find all orders placed in the year 2005 in the orders database.

# %%
# Just 2005
pd.read_sql("""
SELECT *
  FROM orders
    WHERE strftime('%Y', orderDate) = '2005';
""", conn)
# Out:
#     orderNumber   orderDate requiredDate shippedDate      status  \
# 0         10362  2005-01-05   2005-01-16  2005-01-10     Shipped
# 1         10363  2005-01-06   2005-01-12  2005-01-10     Shipped
# 2         10364  2005-01-06   2005-01-17  2005-01-09     Shipped
# 3         10365  2005-01-07   2005-01-18  2005-01-11     Shipped
# 4         10366  2005-01-10   2005-01-19  2005-01-12     Shipped
# ..          ...         ...          ...         ...         ...
# 59        10421  2005-05-29   2005-06-06              In Process
# 60        10422  2005-05-30   2005-06-11              In Process
# 61        10423  2005-05-30   2005-06-05              In Process
# 62        10424  2005-05-31   2005-06-08              In Process
# 63        10425  2005-05-31   2005-06-07              In Process
#
#                                              comments  customerNumber
# 0                                                                 161
# 1                                                                 334
# 2                                                                 350
# 3                                                                 320
# 4                                                                 381
# ..                                                ...             ...
# 59  Custom shipping instructions were sent to ware...             124
# 60                                                                157
# 61                                                                314
# 62                                                                141
# 63                                                                119
#
# [64 rows x 7 columns]

# %% [markdown]
# 6. Going back to the employees database, use LIKE to find all of those who have sale or sales in their job title.

# %%
# Using sales with wildcard
pd.read_sql("""
SELECT *
 FROM employees
WHERE jobTitle LIKE "%sale%";
""", conn)
# Out:
#     employeeNumber   lastName firstName extension  \
# 0             1056  Patterson      Mary     x4611
# 1             1088  Patterson   William     x4871
# 2             1102     Bondur    Gerard     x5408
# 3             1143        Bow   Anthony     x5428
# 4             1165   Jennings    Leslie     x3291
# 5             1166   Thompson    Leslie     x4065
# 6             1188   Firrelli     Julie     x2173
# 7             1216  Patterson     Steve     x4334
# 8             1286      Tseng  Foon Yue     x2248
# 9             1323     Vanauf    George     x4102
# 10            1337     Bondur      Loui     x6493
# 11            1370  Hernandez    Gerard     x2028
# 12            1401   Castillo    Pamela     x2759
# 13            1501       Bott     Larry     x2311
# 14            1504      Jones     Barry      x102
# 15            1611     Fixter      Andy      x101
# 16            1612      Marsh     Peter      x102
# 17            1619       King       Tom      x103
# 18            1621      Nishi      Mami      x101
# 19            1625       Kato   Yoshimi      x102
# 20            1702     Gerard    Martin     x2312
#
#                               email  officeCode  reportsTo  \
# 0    mpatterso@classicmodelcars.com           1       1002
# 1   wpatterson@classicmodelcars.com           6       1056
# 2      gbondur@classicmodelcars.com           4       1056
# 3         abow@classicmodelcars.com           1       1056
# 4    ljennings@classicmodelcars.com           1       1143
# 5    lthompson@classicmodelcars.com           1       1143
# 6    jfirrelli@classicmodelcars.com           2       1143
# 7   spatterson@classicmodelcars.com           2       1143
# 8       ftseng@classicmodelcars.com           3       1143
# 9      gvanauf@classicmodelcars.com           3       1143
# 10     lbondur@classicmodelcars.com           4       1102
# 11   ghernande@classicmodelcars.com           4       1102
# 12   pcastillo@classicmodelcars.com           4       1102
# 13       lbott@classicmodelcars.com           7       1102
# 14      bjones@classicmodelcars.com           7       1102
# 15     afixter@classicmodelcars.com           6       1088
# 16      pmarsh@classicmodelcars.com           6       1088
# 17       tking@classicmodelcars.com           6       1088
# 18      mnishi@classicmodelcars.com           5       1056
# 19       ykato@classicmodelcars.com           5       1621
# 20     mgerard@classicmodelcars.com           4       1102
#
#                 jobTitle
# 0               VP Sales
# 1   Sales Manager (APAC)
# 2    Sale Manager (EMEA)
# 3     Sales Manager (NA)
# 4              Sales Rep
# 5              Sales Rep
# 6              Sales Rep
# 7              Sales Rep
# 8              Sales Rep
# 9              Sales Rep
# 10             Sales Rep
# 11             Sales Rep
# 12             Sales Rep
# 13             Sales Rep
# 14             Sales Rep
# 15             Sales Rep
# 16             Sales Rep
# 17             Sales Rep
# 18             Sales Rep
# 19             Sales Rep
# 20             Sales Rep

# %% [markdown]
# 7. Now find out how many items are priced at least $200 in the orderDetails database.

# %%
# Count each
pd.read_sql("""
SELECT COUNT(priceEach)
 FROM orderDetails
WHERE priceEach >= 200;
""", conn)
# Out:
#    COUNT(priceEach)
# 0                20

# %%
conn.close()
